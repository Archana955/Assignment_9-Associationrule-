# %% [markdown]
#   **Prepare rules for the all the data sets**
#
# **1) Try different values of support and confidence. Observe the change in number of rules for different support,confidence values**
#
# **2) Change the minimum length in apriori algorithm**
#
# **3) Visulize the obtained rules using different plots**

# %% [markdown]
# # **Book Dataset**

# %% [markdown]
# # **Import libraries**

# %%
# !pip install mlxtend

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # **Importing File**

# %%
from google.colab import files
uploaded=files.upload()

# %%
book = pd.read_csv('book.csv')
book.head()

# %%
book.shape

# %% [markdown]
# # **Aprori Algorithm**

# %%
frequent_itemsets_ap = apriori(book, min_support = 0.1)

# %%
print(len(frequent_itemsets_ap))

# %%
frequent_itemsets_ap = apriori(book, min_support=0.1, use_colnames= True)
print(frequent_itemsets_ap.head())

# %%
frequent_itemsets_ap.sort_values("support", ascending = False)

# %%
rules_ap = association_rules(frequent_itemsets_ap, metric= "confidence", min_threshold=0.4)
print(rules_ap.head())

# %%
rules_ap[(rules_ap.support > 0.015) & (rules_ap.confidence > 0.4)].sort_values("confidence", ascending = False).shape

# %%
rules_ap['lhs items'] = rules_ap['antecedents'].apply(lambda x:len(x) )
rules_ap[rules_ap['lhs items']>1].sort_values('lift', ascending=False).head()

# %%
import matplotlib.pyplot as plt
rules_ap[['support','confidence','lift']].hist(figsize=(15,7))
plt.show()

# %%
rules_ap_li = association_rules(frequent_itemsets_ap, metric="lift", min_threshold=0.6)
print(rules_ap_li.shape)

# %%
rules_ap_li['lhs items'] = rules_ap_li['antecedents'].apply(lambda x:len(x) )
rules_ap_li[rules_ap_li['lhs items']>1].sort_values('lift', ascending=False).head()

# %%
import matplotlib.pyplot as plt
rules_ap_li[['support','confidence','lift']].hist(figsize=(15,7))
plt.show()

# %% [markdown]
# # **My movies Dataset**

# %%
from google.colab import files
uploaded=files.upload()

# %%
movie=pd.read_csv('my_movies.csv')
movie.head()

# %%
num_movie = movie.iloc[:,5:15]
num_movie.head()

# %% [markdown]
# # **Apriori Algorithm**

# %%
frequent_itemsets_ap = apriori(num_movie, min_support=0.15, use_colnames=True)
print(frequent_itemsets_ap.head())

# %%
frequent_itemsets_ap.sort_values("support", ascending = False).shape

# %%
rules_aps = association_rules(frequent_itemsets_ap, metric="confidence", min_threshold=0.1)
print(rules_ap.head())

# %%
rules_aps[(rules_ap.support > 0.015) & (rules_ap.confidence > 0.4)].sort_values("confidence", ascending = False).shape

# %%
rules_aps['lhs items'] = rules_ap['antecedents'].apply(lambda x:len(x) )
rules_aps[rules_aps['lhs items']>1].sort_values('lift', ascending=False).head()

# %%
import matplotlib.pyplot as plt
rules_aps[['support','confidence','lift']].hist(figsize=(15,7))
plt.show()

# %%
rules_aps_li = association_rules(frequent_itemsets_ap, metric="lift", min_threshold=0.8)
print(rules_aps_li.shape)

# %%
rules_aps_li['lhs items'] = rules_ap['antecedents'].apply(lambda x:len(x) )
rules_aps_li[rules_aps['lhs items']>1].sort_values('lift', ascending=False).head()

# %%
import matplotlib.pyplot as plt
rules_aps_li[['support','confidence','lift']].hist(figsize=(15,7))
plt.show()
